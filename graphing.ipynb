# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/testsetallwaves_sr22050.csv")
df_white = pd.read_csv("data/trainsetwhitenoise_sr22050.csv")

# %%
plt.plot(df_white.loc[10000:11000,"pre_filter"], label="pre")
plt.plot(df_white.loc[10000:11000,"post_filter"], label="post")
plt.legend()
